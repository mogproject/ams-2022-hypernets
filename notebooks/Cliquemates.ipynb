# %%
# %run ../mates_finder_lib.py

# %%
visualize_adj(get_adj(4, 10, 4957252556))

# %%
visualize_adj(get_adj(4, 10, 5208845261))

# %%
visualize_adj(get_adj(4, 10, 13765221086))

# %%
visualize_adj(get_adj(4, 10, 13780945886))

# %%
visualize_adj(get_adj(4, 10, 78189726686))

# %%
visualize_adj(get_adj(4, 10, 13780949711))

# %%
visualize_adj(get_adj(4, 10, 78189730511))

# %%
visualize_adj(get_adj(4, 10, 78205455311))

# %%
visualize_adj(get_adj(4, 10, 82483645151))
